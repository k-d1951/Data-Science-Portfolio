# %%
# https://www.kaggle.com/c/ngsa-2018

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import re
import itertools

from gensim import corpora, models, similarities
import networkx as nx
from networkx.algorithms.connectivity import local_edge_connectivity
from networkx.algorithms.connectivity import build_auxiliary_edge_connectivity
from networkx.algorithms.flow import build_residual_network
import igraph

import nltk
from nltk.corpus import stopwords
stopwords = stopwords.words("english")
#nltk.download('punkt') # for tokenization

from sklearn import svm
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn import preprocessing

# %% [markdown]
# # Import data

# %%
nodes_header = ["id", "year", "title", "authors", "journal", "abstract"]
node_info = pd.read_csv('node_information.csv',names=nodes_header)
node_info.set_index("id", inplace=True)

# %%
node_info.head()
# Out:
#       year                                              title  \
# id
# 1001  2000              compactification geometry and duality
# 1002  2000  domain walls and massive gauged supergravity p...
# 1003  2000     comment on metric fluctuations in brane worlds
# 1004  2000         moving mirrors and thermodynamic paradoxes
# 1005  2000  bundles of chiral blocks and boundary conditio...
#
#                           authors            journal  \
# id
# 1001            Paul S. Aspinwall                NaN
# 1002  M. Cvetic, H. Lu, C.N. Pope  Class.Quant.Grav.
# 1003     Y.S. Myung, Gungwon Kang                NaN
# 1004               Adam D. Helfer          Phys.Rev.
# 1005      J. Fuchs, C. Schweigert                NaN
#
#                                                abstract  \
# id
# 1001  these are notes based on lectures given at tas...
# 1002  we point out that massive gauged supergravity ...
# 1003  recently ivanov and volovich hep-th 9912242 cl...
# 1004  quantum fields responding to moving mirrors ha...
# 1005  proceedings of lie iii clausthal july 1999 var...
#
#                                           clean_titles  \
# id
# 1001                    [compactif, geometri, dualiti]
# 1002  [domain, wall, massiv, gaug, supergrav, potenti]
# 1003         [comment, metric, fluctuat, brane, world]
# 1004              [move, mirror, thermodynam, paradox]
# 1005     [bundl, chiral, block, boundari, condit, cft]
#
#                                         clean_abstracts  \
# id
# 1001  [note, base, lectur, given, tasi, review, geom...
# 1002  [point, massiv, gaug, supergrav, potenti, exam...
# 1003  [recent, ivanov, volovich, hep, th, claim, per...
# 1004  [quantum, field, respond, move, mirror, predic...
# 1005  [proceed, lie, iii, clausthal, juli, variou, a...
#
#                         split_authors
# id
# 1001              [Paul S. Aspinwall]
# 1002  [M. Cvetic,  H. Lu,  C.N. Pope]
# 1003      [Y.S. Myung,  Gungwon Kang]
# 1004                 [Adam D. Helfer]
# 1005       [J. Fuchs,  C. Schweigert]

# %%
names = ["id1","id2","category"]
train = pd.read_csv('training_set.txt', names=names,delimiter=" ")
train["index"] = train["id1"].astype(str) + "|" + train["id2"].astype(str)
train.set_index("index", inplace=True)
train_size=615512

name = ["id1","id2"]
test = pd.read_csv('testing_set.txt',names=name,delimiter=" ")

# %% [markdown]
# # Preprossing

# %%
# this part is to do some cleaning on titles and abstract

stemmer = nltk.porter.PorterStemmer()

def cleaning(text):
    # split and lower the text
    text= text.apply(lambda sentence:  "".join((char if char.isalpha() else " ") for char in sentence).lower().split() )
    # remove stopwords
    text = text.apply(lambda words : [word for word in words if word not in stopwords])
    # stemmer
    text = text.apply(lambda words : [stemmer.stem(word) for word in words])
    return text

# %%
                                     # -----clean title----- #
titles = cleaning(node_info['title'])
node_info['clean_titles'] = titles

                                     # -----clean abstract---- #
abstracts = cleaning(node_info['abstract'])
node_info['clean_abstracts'] = abstracts

                                     # -----split authors---- #
authors = node_info['authors'].astype(str).str.split(',')
node_info['split_authors'] = authors

# %% [markdown]
# # Generate Features

# %% [markdown]
# ## citation graph features

# %% [markdown]
# ### shortest path in citation graph

# %%
# create graph of citations

shortest_path=[]
id1 = train['id1'].values
id2 = train['id2'].values

# create empty directed graph
g = igraph.Graph(directed=True)

# create the nodes of the graph from node_info
nodes = node_info.index.values
str_vec = np.vectorize(str)
nodes = str_vec(nodes)

# add vertices
g.add_vertices(nodes)

# create and add edges
edges = [(str(id1[i]), str(id2[i])) for i in range(len(id1)) if train['category'][i] == 1]
g.add_edges(edges)

vs = dict(zip(nodes, range(len(nodes))))

#di_network_graph = nx.DiGraph() 
#di_network_graph.add_nodes_from(nodes)
#di_network_graph.add_edges_from(edges)

#un_network_graph = nx.Graph() 
#un_network_graph.add_nodes_from(nodes)
#un_network_graph.add_edges_from(edges)

# %%
i = 0
print('start computing shortest path')
shortest_path = []
id1 = train['id1'].values
id2 = train['id2'].values
for idx in range(len(id1)):
    shortest_path.append(g.shortest_paths(source=str(id1[idx]), target=str(id2[idx]))[0][0])
    i += 1
    if int(i) % 1000 == 0:
        print(str(100.0*i/train_size)[:4]+"% of the task done", flush=True)
    
# categorize shortest path into different categories
shortest_dist_3 = [1 if d <= 3 else 0 for d in shortest_path]
shortest_dist_5 = [1 if d <= 5 and d > 3 else 0 for d in shortest_path]
shortest_dist_10 = [1 if d <= 10 and d > 5 else 0 for d in shortest_path]
shortest_dist_inf = [1 if d > 10 else 0 for d in shortest_path]

train['shortest_path_3'] = shortest_dist_3
train['shortest_path_5'] = shortest_dist_5
train['shortest_path_10'] = shortest_dist_10
train['shortest_path_inf'] = shortest_dist_inf
# Out:
# start computing shortest path
# 0.16% of the task done
# 0.32% of the task done
# 0.48% of the task done
# 0.64% of the task done
# 0.81% of the task done
# 0.97% of the task done
# 1.13% of the task done
# 1.29% of the task done
# 1.46% of the task done
# 1.62% of the task done
# 1.78% of the task done
# 1.94% of the task done
# 2.11% of the task done
# 2.27% of the task done
# 2.43% of the task done
# 2.59% of the task done
# 2.76% of the task done
# 2.92% of the task done
# 3.08% of the task done
# 3.24% of the task done
# 3.41% of the task done
# 3.57% of the task done
# 3.73% of the task done
# 3.89% of the task done
# 4.06% of the task done
# 4.22% of the task done
# 4.38% of the task done
# 4.54% of the task done
# 4.71% of the task done
# 4.87% of the task done
# 5.03% of the task done
# 5.19% of the task done
# 5.36% of the task done
# 5.52% of the task done
# 5.68% of the task done
# 5.84% of the task done
# 6.01% of the task done
# 6.17% of the task done
# 6.33% of the task done
# 6.49% of the task done
# 6.66% of the task done
# 6.82% of the task done
# 6.98% of the task done
# 7.14% of the task done
# 7.31% of the task done
# 7.47% of the task done
# 7.63% of the task done
# 7.79% of the task done
# 7.96% of the task done
# 8.12% of the task done
# 8.28% of the task done
# 8.44% of the task done
# 8.61% of the task done
# 8.77% of the task done
# 8.93% of the task done
# 9.09% of the task done
# 9.26% of the task done
# 9.42% of the task done
# 9.58% of the task done
# 9.74% of the task done
# 9.91% of the task done
# 10.0% of the task done
# 10.2% of the task done
# 10.3% of the task done
# 10.5% of the task done
# 10.7% of the task done
# 10.8% of the task done
# 11.0% of the task done
# 11.2% of the task done
# 11.3% of the task done
# 11.5% of the task done
# 11.6% of the task done
# 11.8% of the task done
# 12.0% of the task done
# 12.1% of the task done
# 12.3% of the task done
# 12.5% of the task done
# 12.6% of the task done
# 12.8% of the task done
# 12.9% of the task done
# 13.1% of the task done
# 13.3% of the task done
# 13.4% of the task done
# 13.6% of the task done
# 13.8% of the task done
# 13.9% of the task done
# 14.1% of the task done
# 14.2% of the task done
# 14.4% of the task done
# 14.6% of the task done
# 14.7% of the task done
# 14.9% of the task done
# 15.1% of the task done
# 15.2% of the task done
# 15.4% of the task done
# 15.5% of the task done
# 15.7% of the task done
# 15.9% of the task done
# 16.0% of the task done
# 16.2% of the task done
# 16.4% of the task done
# 16.5% of the task done
# 16.7% of the task done
# 16.8% of the task done
# 17.0% of the task done
# 17.2% of the task done
# 17.3% of the task done
# 17.5% of the task done
# 17.7% of the task done
# 17.8% of the task done
# 18.0% of the task done
# 18.1% of the task done
# 18.3% of the task done
# 18.5% of the task done
# 18.6% of the task done
# 18.8% of the task done
# 19.0% of the task done
# 19.1% of the task done
# 19.3% of the task done
# 19.4% of the task done
# 19.6% of the task done
# 19.8% of the task done
# 19.9% of the task done
# 20.1% of the task done
# 20.3% of the task done
# 20.4% of the task done
# 20.6% of the task done
# 20.7% of the task done
# 20.9% of the task done
# 21.1% of the task done
# 21.2% of the task done
# 21.4% of the task done
# 21.6% of the task done
# 21.7% of the task done
# 21.9% of the task done
# 22.0% of the task done
# 22.2% of the task done
# 22.4% of the task done
# 22.5% of the task done
# 22.7% of the task done
# 22.9% of the task done
# 23.0% of the task done
# 23.2% of the task done
# 23.3% of the task done
# 23.5% of the task done
# 23.7% of the task done
# 23.8% of the task done
# 24.0% of the task done
# 24.2% of the task done
# 24.3% of the task done
# 24.5% of the task done
# 24.6% of the task done
# 24.8% of the task done
# 25.0% of the task done
# 25.1% of the task done
# 25.3% of the task done
# 25.5% of the task done
# 25.6% of the task done
# 25.8% of the task done
# 25.9% of the task done
# 26.1% of the task done
# 26.3% of the task done
# 26.4% of the task done
# 26.6% of the task done
# 26.8% of the task done
# 26.9% of the task done
# 27.1% of the task done
# 27.2% of the task done
# 27.4% of the task done
# 27.6% of the task done
# 27.7% of the task done
# 27.9% of the task done
# 28.1% of the task done
# 28.2% of the task done
# 28.4% of the task done
# 28.5% of the task done
# 28.7% of the task done
# 28.9% of the task done
# 29.0% of the task done
# 29.2% of the task done
# 29.4% of the task done
# 29.5% of the task done
# 29.7% of the task done
# 29.8% of the task done
# 30.0% of the task done
# 30.2% of the task done
# 30.3% of the task done
# 30.5% of the task done
# 30.7% of the task done
# 30.8% of the task done
# 31.0% of the task done
# 31.1% of the task done
# 31.3% of the task done
# 31.5% of the task done
# 31.6% of the task done
# 31.8% of the task done
# 32.0% of the task done
# 32.1% of the task done
# 32.3% of the task done
# 32.4% of the task done
# 32.6% of the task done
# 32.8% of the task done
# 32.9% of the task done
# 33.1% of the task done
# 33.3% of the task done
# 33.4% of the task done
# 33.6% of the task done
# 33.7% of the task done
# 33.9% of the task done
# 34.1% of the task done
# 34.2% of the task done
# 34.4% of the task done
# 34.6% of the task done
# 34.7% of the task done
# 34.9% of the task done
# 35.0% of the task done
# 35.2% of the task done
# 35.4% of the task done
# 35.5% of the task done
# 35.7% of the task done
# 35.9% of the task done
# 36.0% of the task done
# 36.2% of the task done
# 36.3% of the task done
# 36.5% of the task done
# 36.7% of the task done
# 36.8% of the task done
# 37.0% of the task done
# 37.2% of the task done
# 37.3% of the task done
# 37.5% of the task done
# 37.6% of the task done
# 37.8% of the task done
# 38.0% of the task done
# 38.1% of the task done
# 38.3% of the task done
# 38.5% of the task done
# 38.6% of the task done
# 38.8% of the task done
# 38.9% of the task done
# 39.1% of the task done
# 39.3% of the task done
# 39.4% of the task done
# 39.6% of the task done
# 39.8% of the task done
# 39.9% of the task done
# 40.1% of the task done
# 40.2% of the task done
# 40.4% of the task done
# 40.6% of the task done
# 40.7% of the task done
# 40.9% of the task done
# 41.1% of the task done
# 41.2% of the task done
# 41.4% of the task done
# 41.5% of the task done
# 41.7% of the task done
# 41.9% of the task done
# 42.0% of the task done
# 42.2% of the task done
# 42.4% of the task done
# 42.5% of the task done
# 42.7% of the task done
# 42.8% of the task done
# 43.0% of the task done
# 43.2% of the task done
# 43.3% of the task done
# 43.5% of the task done
# 43.7% of the task done
# 43.8% of the task done
# 44.0% of the task done
# 44.1% of the task done
# 44.3% of the task done
# 44.5% of the task done
# 44.6% of the task done
# 44.8% of the task done
# 45.0% of the task done
# 45.1% of the task done
# 45.3% of the task done
# 45.4% of the task done
# 45.6% of the task done
# 45.8% of the task done
# 45.9% of the task done
# 46.1% of the task done
# 46.3% of the task done
# 46.4% of the task done
# 46.6% of the task done
# 46.7% of the task done
# 46.9% of the task done
# 47.1% of the task done
# 47.2% of the task done
# 47.4% of the task done
# 47.6% of the task done
# 47.7% of the task done
# 47.9% of the task done
# 48.0% of the task done
# 48.2% of the task done
# 48.4% of the task done
# 48.5% of the task done
# 48.7% of the task done
# 48.9% of the task done
# 49.0% of the task done
# 49.2% of the task done
# 49.3% of the task done
# 49.5% of the task done
# 49.7% of the task done
# 49.8% of the task done
# 50.0% of the task done
# 50.2% of the task done
# 50.3% of the task done
# 50.5% of the task done
# 50.6% of the task done
# 50.8% of the task done
# 51.0% of the task done
# 51.1% of the task done
# 51.3% of the task done
# 51.5% of the task done
# 51.6% of the task done
# 51.8% of the task done
# 51.9% of the task done
# 52.1% of the task done
# 52.3% of the task done
# 52.4% of the task done
# 52.6% of the task done
# 52.8% of the task done
# 52.9% of the task done
# 53.1% of the task done
# 53.2% of the task done
# 53.4% of the task done
# 53.6% of the task done
# 53.7% of the task done
# 53.9% of the task done
# 54.1% of the task done
# 54.2% of the task done
# 54.4% of the task done
# 54.5% of the task done
# 54.7% of the task done
# 54.9% of the task done
# 55.0% of the task done
# 55.2% of the task done
# 55.4% of the task done
# 55.5% of the task done
# 55.7% of the task done
# 55.8% of the task done
# 56.0% of the task done
# 56.2% of the task done
# 56.3% of the task done
# 56.5% of the task done
# 56.7% of the task done
# 56.8% of the task done
# 57.0% of the task done
# 57.1% of the task done
# 57.3% of the task done
# 57.5% of the task done
# 57.6% of the task done
# 57.8% of the task done
# 58.0% of the task done
# 58.1% of the task done
# 58.3% of the task done
# 58.4% of the task done
# 58.6% of the task done
# 58.8% of the task done
# 58.9% of the task done
# 59.1% of the task done
# 59.3% of the task done
# 59.4% of the task done
# 59.6% of the task done
# 59.7% of the task done
# 59.9% of the task done
# 60.1% of the task done
# 60.2% of the task done
# 60.4% of the task done
# 60.5% of the task done
# 60.7% of the task done
# 60.9% of the task done
# 61.0% of the task done
# 61.2% of the task done
# 61.4% of the task done
# 61.5% of the task done
# 61.7% of the task done
# 61.8% of the task done
# 62.0% of the task done
# 62.2% of the task done
# 62.3% of the task done
# 62.5% of the task done
# 62.7% of the task done
# 62.8% of the task done
# 63.0% of the task done
# 63.1% of the task done
# 63.3% of the task done
# 63.5% of the task done
# 63.6% of the task done
# 63.8% of the task done
# 64.0% of the task done
# 64.1% of the task done
# 64.3% of the task done
# 64.4% of the task done
# 64.6% of the task done
# 64.8% of the task done
# 64.9% of the task done
# 65.1% of the task done
# 65.3% of the task done
# 65.4% of the task done
# 65.6% of the task done
# 65.7% of the task done
# 65.9% of the task done
# 66.1% of the task done
# 66.2% of the task done
# 66.4% of the task done
# 66.6% of the task done
# 66.7% of the task done
# 66.9% of the task done
# 67.0% of the task done
# 67.2% of the task done
# 67.4% of the task done
# 67.5% of the task done
# 67.7% of the task done
# 67.9% of the task done
# 68.0% of the task done
# 68.2% of the task done
# 68.3% of the task done
# 68.5% of the task done
# 68.7% of the task done
# 68.8% of the task done
# 69.0% of the task done
# 69.2% of the task done
# 69.3% of the task done
# 69.5% of the task done
# 69.6% of the task done
# 69.8% of the task done
# 70.0% of the task done
# 70.1% of the task done
# 70.3% of the task done
# 70.5% of the task done
# 70.6% of the task done
# 70.8% of the task done
# 70.9% of the task done
# 71.1% of the task done
# 71.3% of the task done
# 71.4% of the task done
# 71.6% of the task done
# 71.8% of the task done
# 71.9% of the task done
# 72.1% of the task done
# 72.2% of the task done
# 72.4% of the task done
# 72.6% of the task done
# 72.7% of the task done
# 72.9% of the task done
# 73.1% of the task done
# 73.2% of the task done
# 73.4% of the task done
# 73.5% of the task done
# 73.7% of the task done
# 73.9% of the task done
# 74.0% of the task done
# 74.2% of the task done
# 74.4% of the task done
# 74.5% of the task done
# 74.7% of the task done
# 74.8% of the task done
# 75.0% of the task done
# 75.2% of the task done
# 75.3% of the task done
# 75.5% of the task done
# 75.7% of the task done
# 75.8% of the task done
# 76.0% of the task done
# 76.1% of the task done
# 76.3% of the task done
# 76.5% of the task done
# 76.6% of the task done
# 76.8% of the task done
# 77.0% of the task done
# 77.1% of the task done
# 77.3% of the task done
# 77.4% of the task done
# 77.6% of the task done
# 77.8% of the task done
# 77.9% of the task done
# 78.1% of the task done
# 78.3% of the task done
# 78.4% of the task done
# 78.6% of the task done
# 78.7% of the task done
# 78.9% of the task done
# 79.1% of the task done
# 79.2% of the task done
# 79.4% of the task done
# 79.6% of the task done
# 79.7% of the task done
# 79.9% of the task done
# 80.0% of the task done
# 80.2% of the task done
# 80.4% of the task done
# 80.5% of the task done
# 80.7% of the task done
# 80.9% of the task done
# 81.0% of the task done
# 81.2% of the task done
# 81.3% of the task done
# 81.5% of the task done
# 81.7% of the task done
# 81.8% of the task done
# 82.0% of the task done
# 82.2% of the task done
# 82.3% of the task done
# 82.5% of the task done
# 82.6% of the task done
# 82.8% of the task done
# 83.0% of the task done
# 83.1% of the task done
# 83.3% of the task done
# 83.5% of the task done
# 83.6% of the task done
# 83.8% of the task done
# 83.9% of the task done
# 84.1% of the task done
# 84.3% of the task done
# 84.4% of the task done
# 84.6% of the task done
# 84.8% of the task done
# 84.9% of the task done
# 85.1% of the task done
# 85.2% of the task done
# 85.4% of the task done
# 85.6% of the task done
# 85.7% of the task done
# 85.9% of the task done
# 86.1% of the task done
# 86.2% of the task done
# 86.4% of the task done
# 86.5% of the task done
# 86.7% of the task done
# 86.9% of the task done
# 87.0% of the task done
# 87.2% of the task done
# 87.4% of the task done
# 87.5% of the task done
# 87.7% of the task done
# 87.8% of the task done
# 88.0% of the task done
# 88.2% of the task done
# 88.3% of the task done
# 88.5% of the task done
# 88.7% of the task done
# 88.8% of the task done
# 89.0% of the task done
# 89.1% of the task done
# 89.3% of the task done
# 89.5% of the task done
# 89.6% of the task done
# 89.8% of the task done
# 90.0% of the task done
# 90.1% of the task done
# 90.3% of the task done
# 90.4% of the task done
# 90.6% of the task done
# 90.8% of the task done
# 90.9% of the task done
# 91.1% of the task done
# 91.3% of the task done
# 91.4% of the task done
# 91.6% of the task done
# 91.7% of the task done
# 91.9% of the task done
# 92.1% of the task done
# 92.2% of the task done
# 92.4% of the task done
# 92.6% of the task done
# 92.7% of the task done
# 92.9% of the task done
# 93.0% of the task done
# 93.2% of the task done
# 93.4% of the task done
# 93.5% of the task done
# 93.7% of the task done
# 93.9% of the task done
# 94.0% of the task done
# 94.2% of the task done
# 94.3% of the task done
# 94.5% of the task done
# 94.7% of the task done
# 94.8% of the task done
# 95.0% of the task done
# 95.2% of the task done
# 95.3% of the task done
# 95.5% of the task done
# 95.6% of the task done
# 95.8% of the task done
# 96.0% of the task done
# 96.1% of the task done
# 96.3% of the task done
# 96.5% of the task done
# 96.6% of the task done
# 96.8% of the task done
# 96.9% of the task done
# 97.1% of the task done
# 97.3% of the task done
# 97.4% of the task done
# 97.6% of the task done
# 97.8% of the task done
# 97.9% of the task done
# 98.1% of the task done
# 98.2% of the task done
# 98.4% of the task done
# 98.6% of the task done
# 98.7% of the task done
# 98.9% of the task done
# 99.1% of the task done
# 99.2% of the task done
# 99.4% of the task done
# 99.5% of the task done
# 99.7% of the task done
# 99.9% of the task done

# %%
print('start computing shortest path in test set')
shortest_path_test = []
id1 = test['id1'].values
id2 = test['id2'].values
for idx in range(len(id1)):
    shortest_path_test.append(g.shortest_paths(source=str(id1[idx]), target=str(id2[idx]))[0][0])
    i += 1
    if int(i) % 1000 == 0:
        print(str(100.0*i/32648)[:4]+"% of the task done", flush=True)
    
# categorize shortest path into different categories
shortest_dist_3_test = [1 if d <= 3 else 0 for d in shortest_path_test]
shortest_dist_5_test = [1 if d <= 5 and d > 3 else 0 for d in shortest_path_test]
shortest_dist_10_test = [1 if d <= 10 and d > 5 else 0 for d in shortest_path_test]
shortest_dist_inf_test = [1 if d > 10 else 0 for d in shortest_path_test]

test['shortest_path_3'] = shortest_dist_3_test
test['shortest_path_5'] = shortest_dist_5_test
test['shortest_path_10'] = shortest_dist_10_test
test['shortest_path_inf'] = shortest_dist_inf_test
# Out:
# start computing shortest path in test set
# 1886% of the task done
# 1889% of the task done
# 1892% of the task done
# 1895% of the task done
# 1899% of the task done
# 1902% of the task done
# 1905% of the task done
# 1908% of the task done
# 1911% of the task done
# 1914% of the task done
# 1917% of the task done
# 1920% of the task done
# 1923% of the task done
# 1926% of the task done
# 1929% of the task done
# 1932% of the task done
# 1935% of the task done
# 1938% of the task done
# 1941% of the task done
# 1944% of the task done
# 1948% of the task done
# 1951% of the task done
# 1954% of the task done
# 1957% of the task done
# 1960% of the task done
# 1963% of the task done
# 1966% of the task done
# 1969% of the task done
# 1972% of the task done
# 1975% of the task done
# 1978% of the task done
# 1981% of the task done
# 1984% of the task done

# %% [markdown]
# ### difference of in-degree / number of times id2 paper is citated

# %%
id1 = train['id1'].values
id2 = train['id2'].values
print('start computing in-degree and number of times id2 paper is citated')
degrees_vs = g.indegree()
degrees_id1 = [degrees_vs[vs[str(id1)]] for id1 in id1]
degrees_id2 = [degrees_vs[vs[str(id2)]] for id2 in id2]
diff_degrees = [a-b for a,b in zip(degrees_id1,degrees_id2)]

train['diff_indegree'] = diff_degrees
train['id2_cite'] = degrees_id2 # number of times id2 paper is cited
# Out:
# start computing in-degree and number of times id2 paper is citated

# %%
id1_t = test['id1'].values
id2_t = test['id2'].values
print('start computing in-degree and number of times id2 paper is citated')
degrees_vs = g.indegree()
degrees_id1_t = [degrees_vs[vs[str(id1_t)]] for id1_t in id1_t]
degrees_id2_t = [degrees_vs[vs[str(id2_t)]] for id2_t in id2_t]
diff_degrees_t = [a-b for a,b in zip(degrees_id1_t,degrees_id2_t)]

test['diff_indegree'] = diff_degrees_t
test['id2_cite'] = degrees_id2_t # number of times id2 paper is cited
# Out:
# start computing in-degree and number of times id2 paper is citated

# %% [markdown]
# ### difference in between centrality

# %%
                             #---- directed between centrality difference ---- #
di_between_centrality = g.betweenness(directed=True)
di_b_centrality_id1 = np.array([di_between_centrality[vs[str(nodeid)]] for nodeid in id1])
di_b_centrality_id2 = np.array([di_between_centrality[vs[str(nodeid)]] for nodeid in id2])
diff_di_b_centrality = di_b_centrality_id2 - di_b_centrality_id1
train['diff_di_b_centrality'] = diff_di_b_centrality

                             #---- directed between centrality difference ---- #
un_between_centrality = g.betweenness(directed=False)
un_b_centrality_id1 = np.array([un_between_centrality[vs[str(nodeid)]] for nodeid in id1])
un_b_centrality_id2 = np.array([un_between_centrality[vs[str(nodeid)]] for nodeid in id2])
diff_un_b_centrality = un_b_centrality_id2 - un_b_centrality_id1
train['diff_un_b_centrality'] = diff_un_b_centrality

# %%
                             #---- directed between centrality difference ---- #
di_between_centrality = g.betweenness(directed=True)
di_b_centrality_id1_t = np.array([di_between_centrality[vs[str(nodeid)]] for nodeid in id1_t])
di_b_centrality_id2_t = np.array([di_between_centrality[vs[str(nodeid)]] for nodeid in id2_t])
diff_di_b_centrality_t = di_b_centrality_id2_t - di_b_centrality_id1_t
test['diff_di_b_centrality'] = diff_di_b_centrality_t

                             #---- directed between centrality difference ---- #
un_between_centrality = g.betweenness(directed=False)
un_b_centrality_id1_t = np.array([un_between_centrality[vs[str(nodeid)]] for nodeid in id1_t])
un_b_centrality_id2_t = np.array([un_between_centrality[vs[str(nodeid)]] for nodeid in id2_t])
diff_un_b_centrality_t = un_b_centrality_id2_t - un_b_centrality_id1_t
test['diff_un_b_centrality'] = diff_un_b_centrality_t

# %% [markdown]
# ### in the same cluster or not

# %%
# no idea how to do it
